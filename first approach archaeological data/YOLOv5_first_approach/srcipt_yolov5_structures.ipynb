# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/yolov5

# %%
import torch
import os
from IPython.display import Image, clear_output  # to display images

print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.11.0+cu113 (Tesla K80)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/yolov5/
# %pip install -qr requirements.txt # install dependencies
# Out:
# /content/drive/MyDrive/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 200 --data /content/drive/MyDrive/yolov5/data/structures.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/drive/MyDrive/yolov5/data/structures.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=200, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 50 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# ...

# %%
# apply detect

# !python detect.py --weights /content/drive/MyDrive/yolov5/runs/train/exp3/weights/best.pt --source /content/drive/MyDrive/YOLOv5_first_approach/dataset/test/ --save-txt --save-conf
# Out:
# detect: weights=['/content/drive/MyDrive/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/YOLOv5_first_approach/dataset/test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=True, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-157-g7043872 torch 1.11.0+cu113 CUDA:0 (Tesla K80, 11441MiB)
#
# Fusing layers...
# Model summary: 213 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/26 /content/drive/MyDrive/YOLOv5_first_approach/dataset/test/12685_2018_225_Fig4_HTML.jpg: 640x480 7 qanats, Done. (0.029s)
# image 2/26 /content/drive/MyDrive/YOLOv5_first_approach/dataset/test/14935264874_1714cae356_o.jpg: 448x640 2 ruined structures, Done. (0.027s)
# ...

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs/train
